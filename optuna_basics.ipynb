# %% [markdown]
# <a href="https://colab.research.google.com/github/Satish-Kumar-1/Personal-Cancer-Diagnosis/blob/main/optuna_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install optuna
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.8 MB/s eta 0:00:00

# %%
import os
import optuna

import numpy as np
import pandas as pd

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin', 'bmi',
           'diabetespedigreefunction', 'age', 'outcome']

# %%
data = pd.read_csv(url, names = columns)

# %%
data.sample(3)
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 523            9      130             70              0        0  34.2
# 627            0      132             78              0        0  32.4
# 215           12      151             70             40      271  41.8
#
#      diabetespedigreefunction  age  outcome
# 523                     0.652   45        1
# 627                     0.393   21        0
# 215                     0.742   38        1

# %%
#check null values
#We convert 0 to np.nan then handle missing values

def handle_missing_values(data, columns):
    if 0 in data.columns:
        data[columns] = data[compile].replace(0, np.nan)
        data[columns] = data[columns].fillna(data[columns].mean())

    else:
        print(f"{data[columns]} has no missing value ")

    return data[columns]

# %%
handle_missing_values(data, 'glucose')
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: glucose, Length: 768, dtype: int64 has no missing value
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: glucose, Length: 768, dtype: int64

# %%
data.glucose.value_counts()
# Out:
# glucose
# 99     17
# 100    17
# 111    14
# 129    14
# 125    14
#        ..
# 191     1
# 177     1
# 44      1
# 62      1
# 190     1
# Name: count, Length: 136, dtype: int64

# %%
columns = ['glucose', 'bloodpressure', 'skinthickness', 'insulin', 'bmi']

for col in data[columns]:
    data[col] = handle_missing_values(data, col)
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: glucose, Length: 768, dtype: int64 has no missing value
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: bloodpressure, Length: 768, dtype: int64 has no missing value
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: skinthickness, Length: 768, dtype: int64 has no missing value
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: insulin, Length: 768, dtype: int64 has no missing value
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: bmi, Length: 768, dtype: float64 has no missing value

# %%
print(data.isnull().sum())
# Out:
# pregnancies                 0
# glucose                     0
# bloodpressure               0
# skinthickness               0
# insulin                     0
# bmi                         0
# diabetespedigreefunction    0
# age                         0
# outcome                     0
# dtype: int64

# %%
x = data.drop(columns = ['outcome'])
y = data.outcome

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state =42, test_size = 0.2)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
print(f"Training set shape: {x_train.shape}")
print(f"Test set shape: {x_test.shape}")
# Out:
# Training set shape: (614, 8)
# Test set shape: (154, 8)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
# define objective function
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 100)
    max_depth = trial.suggest_int('max_depth', 3, 20)

    model = RandomForestClassifier(
        n_estimators = n_estimators,
        max_depth = max_depth,
        random_state = 42
    )

    score = cross_val_score(model, x_train, y_train, scoring= 'accuracy').mean()

    return score

# %%
study = optuna.create_study(direction = 'maximize', sampler = optuna.samplers.TPESampler())
study.optimize(objective, n_trials = 50)
# Out:
# [I 2024-12-20 13:56:33,166] A new study created in memory with name: no-name-66624c74-5c1f-4397-b3bd-58be4de3cc09
# [I 2024-12-20 13:56:34,453] Trial 0 finished with value: 0.7719978675196588 and parameters: {'n_estimators': 78, 'max_depth': 10}. Best is trial 0 with value: 0.7719978675196588.
# [I 2024-12-20 13:56:36,438] Trial 1 finished with value: 0.7541116886578703 and parameters: {'n_estimators': 67, 'max_depth': 3}. Best is trial 0 with value: 0.7719978675196588.
# [I 2024-12-20 13:56:40,293] Trial 2 finished with value: 0.7785285885645742 and parameters: {'n_estimators': 98, 'max_depth': 7}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:42,701] Trial 3 finished with value: 0.7703851792616286 and parameters: {'n_estimators': 98, 'max_depth': 10}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:45,745] Trial 4 finished with value: 0.7736771957883514 and parameters: {'n_estimators': 95, 'max_depth': 18}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:47,236] Trial 5 finished with value: 0.776915900306544 and parameters: {'n_estimators': 53, 'max_depth': 15}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:50,055] Trial 6 finished with value: 0.7736771957883514 and parameters: {'n_estimators': 98, 'max_depth': 20}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:54,808] Trial 7 finished with value: 0.776915900306544 and parameters: {'n_estimators': 85, 'max_depth': 15}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:56,379] Trial 8 finished with value: 0.752472344395575 and parameters: {'n_estimators': 89, 'max_depth': 3}. Best is trial 2 with value: 0.7785285885645742.
# [I 2024-12-20 13:56:57,075] Trial 9 finished with value: 0.7834732773557244 and parameters: {'n_estimators': 61, 'max_depth': 12}. Best is trial 9 with value: 0.7834732773557244.
# [I 2024-12-20 13:56:57,732] Trial 10 finished with value: 0.7866986538717847 and parameters: {'n_estimators': 60, 'max_depth': 14}. Best is trial 10 with value: 0.7866986538717847.
# [I 2024-12-20 13:56:58,412] Trial 11 finished with value: 0.7834199653471945 and parameters: {'n_estimators': 59, 'max_depth': 14}. Best is trial 10 with value: 0.7866986538717847.
# [I 2024-12-20 13:56:59,159] Trial 12 finished with value: 0.7801812608290017 and parameters: {'n_estimators': 67, 'max_depth': 12}. Best is trial 10 with value: 0.7866986538717847.
# [I 2024-12-20 13:56:59,705] Trial 13 finished with value: 0.7818072770891644 and parameters: {'n_estimators': 51, 'max_depth': 7}. Best is trial 10 with value: 0.7866986538717847.
# [I 2024-12-20 13:57:00,462] Trial 14 finished with value: 0.776942556310809 and parameters: {'n_estimators': 65, 'max_depth': 17}. Best is trial 10 with value: 0.7866986538717847.
. Best is trial 17 with value: 0.7915767026522724.
# [I 2024-12-20 13:57:24,341] Trial 44 finished with value: 0.7899240303878449 and parameters: {'n_estimators': 54, 'max_depth': 11}. Best is trial 17 with value: 0.7915767026522724.
# [I 2024-12-20 13:57:24,983] Trial 45 finished with value: 0.7883113421298147 and parameters: {'n_estimators': 54, 'max_depth': 13}. Best is trial 17 with value: 0.7915767026522724.
# [I 2024-12-20 13:57:25,595] Trial 46 finished with value: 0.7785552445688392 and parameters: {'n_estimators': 53, 'max_depth': 16}. Best is trial 17 with value: 0.7915767026522724.
# [I 2024-12-20 13:57:26,221] Trial 47 finished with value: 0.783433293349327 and parameters: {'n_estimators': 54, 'max_depth': 12}. Best is trial 17 with value: 0.7915767026522724.
# [I 2024-12-20 13:57:26,821] Trial 48 finished with value: 0.776915900306544 and parameters: {'n_estimators': 50, 'max_depth': 14}. Best is trial 17 with value: 0.7915767026522724.
# [I 2024-12-20 13:57:27,520] Trial 49 finished with value: 0.7720378515260562 and parameters: {'n_estimators': 59, 'max_depth': 9}. Best is trial 17 with value: 0.7915767026522724.

# %%
print(f"Best trial accuracy: {study.best_trial.value}")
print(f"Best hyperparameters: {study.best_trial.params}")
# Out:
# Best trial accuracy: 0.7915767026522724
# Best hyperparameters: {'n_estimators': 58, 'max_depth': 13}

# %%
from sklearn.metrics import accuracy_score

best_model = RandomForestClassifier(**study.best_trial.params, random_state = 42)

best_model.fit(x_train, y_train)

y_pred = best_model.predict(x_test)

test_accuracy = accuracy_score(y_test, y_test)

print(f"Test accuracy with best parameters: {test_accuracy*100:.2f}")
# Out:
# Test accuracy with best parameters: 100.00

# %%
# Optimize multiple ML models
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# %%
# define objective function

def objective(trial):
    classifier_name = trial.suggest_categorical('classifier', ['SVM', 'RandomForest', 'GradientBoostingClassifier'])

    if classifier_name == 'SVM':
        c = trial.suggest_float('C', 0.1, 100, log = True)
        kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly', 'sigmoid'])
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])

        model = SVC(C =c,
                    kernel = kernel,
                    gamma = gamma,
                    random_state = 42
        )

    elif classifier_name == 'RandomForest':
       n_estimators = trial.suggest_int('n_estimators', 50, 300)
    #    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log = True)
       max_depth = trial.suggest_int('max_depth', 3, 20)
       min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
       min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
       bootstrap = trial.suggest_categorical('bootstrap', [True, False])

       model = RandomForestClassifier(
           n_estimators = n_estimators,
        #    learning_rate = learning_rate,
           max_depth = max_depth,
           min_samples_leaf = min_samples_leaf,
           min_samples_split = min_samples_split,
           bootstrap = bootstrap,
           random_state =42

       )

    elif classifier_name == 'GradientBoosting':
       n_estimators = trial.suggest_int('n_estimators', 50, 300)
       learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log = True)
       max_depth = trial.suggest_int('max_depth', 3, 20)
       min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
       min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)

       model = GradientBoostingClassifier(
           n_estimators = n_estimators,
           learning_rate = learning_rate,
           max_depth = max_depth,
           min_samples_leaf = min_samples_leaf,
           min_samples_split = min_samples_split,
           random_state =42

       )

       score = cross_val_score(model, x_train, y_train, cv = 3, scoring = 'accuracy').mean()
       return score

# %%
study = optuna.create_study(direction = 'maximize')
study.optimize(objective, n_trials= 50)
# Out:
# [I 2024-12-20 14:21:22,900] A new study created in memory with name: no-name-46e49cf9-a758-4307-9898-cf32a7824750
# [I 2024-12-20 14:21:24,038] Trial 0 finished with value: 0.7556910569105691 and parameters: {'classifier': 'RandomForest', 'n_estimators': 200, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 9, 'bootstrap': True}. Best is trial 0 with value: 0.7556910569105691.
# [I 2024-12-20 14:21:29,122] Trial 1 finished with value: 0.7540730113183485 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 278, 'learning_rate': 0.1194273292916394, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.7556910569105691.
# [I 2024-12-20 14:21:29,245] Trial 2 finished with value: 0.7149689143950263 and parameters: {'classifier': 'SVM', 'C': 87.00843908561433, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.7556910569105691.
# [I 2024-12-20 14:21:30,396] Trial 3 finished with value: 0.7800892714809501 and parameters: {'classifier': 'RandomForest', 'n_estimators': 170, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 10, 'bootstrap': False}. Best is trial 3 with value: 0.7800892714809501.
# [I 2024-12-20 14:21:30,441] Trial 4 finished with value: 0.7572851904989638 and parameters: {'classifier': 'SVM', 'C': 0.1925171655115566, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 3 with value: 0.7800892714809501.
# [I 2024-12-20 14:21:32,367] Trial 5 finished with value: 0.7687230989956958 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 99, 'learning_rate': 0.2757565383736947, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.7800892714809501.
# [I 2024-12-20 14:21:32,907] Trial 6 finished with value: 0.7866092778574845 and parameters: {'classifier': 'RandomForest', 'n_estimators': 98, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:34,359] Trial 7 finished with value: 0.7670811413996493 and parameters: {'classifier': 'RandomForest', 'n_estimators': 251, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:37,532] Trial 8 finished with value: 0.7621951219512195 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 220, 'learning_rate': 0.23085527734125924, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:39,476] Trial 9 finished with value: 0.7426510441575004 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 64, 'learning_rate': 0.033326536217957836, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:40,263] Trial 10 finished with value: 0.7752112227004623 and parameters: {'classifier': 'RandomForest', 'n_estimators': 132, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:41,651] Trial 11 finished with value: 0.7735852064402997 and parameters: {'classifier': 'RandomForest', 'n_estimators': 151, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:42,671] Trial 12 finished with value: 0.7784552845528455 and parameters: {'classifier': 'RandomForest', 'n_estimators': 119, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 10, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:43,183] Trial 13 finished with value: 0.7703252032520326 and parameters: {'classifier': 'RandomForest', 'n_estimators': 54, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 5, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:44,350] Trial 14 finished with value: 0.7833572453371592 and parameters: {'classifier': 'RandomForest', 'n_estimators': 178, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:45,414] Trial 15 finished with value: 0.7784552845528455 and parameters: {'classifier': 'RandomForest', 'n_estimators': 198, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:45,523] Trial 16 finished with value: 0.7654232424677189 and parameters: {'classifier': 'SVM', 'C': 11.89836814150391, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:46,004] Trial 17 finished with value: 0.768683245655986 and parameters: {'classifier': 'RandomForest', 'n_estimators': 86, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 5, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:46,892] Trial 18 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 157, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:46,939] Trial 19 finished with value: 0.7101147776183644 and parameters: {'classifier': 'SVM', 'C': 0.11083249425068263, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:48,192] Trial 20 finished with value: 0.776837238960625 and parameters: {'classifier': 'RandomForest', 'n_estimators': 230, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:49,092] Trial 21 finished with value: 0.7735852064402997 and parameters: {'classifier': 'RandomForest', 'n_estimators': 165, 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:50,087] Trial 22 finished with value: 0.780113183484776 and parameters: {'classifier': 'RandomForest', 'n_estimators': 184, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 6, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:51,080] Trial 23 finished with value: 0.7817391997449387 and parameters: {'classifier': 'RandomForest', 'n_estimators': 189, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 6, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:51,788] Trial 24 finished with value: 0.7833492746692173 and parameters: {'classifier': 'RandomForest', 'n_estimators': 134, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:52,421] Trial 25 finished with value: 0.7800813008130082 and parameters: {'classifier': 'RandomForest', 'n_estimators': 120, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:53,011] Trial 26 finished with value: 0.7638211382113821 and parameters: {'classifier': 'RandomForest', 'n_estimators': 93, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:53,710] Trial 27 finished with value: 0.771967160848079 and parameters: {'classifier': 'RandomForest', 'n_estimators': 132, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:57,572] Trial 28 finished with value: 0.7410250278973378 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 142, 'learning_rate': 0.013040191853581148, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:58,168] Trial 29 finished with value: 0.7719352781763112 and parameters: {'classifier': 'RandomForest', 'n_estimators': 108, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 5, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:58,221] Trial 30 finished with value: 0.6905388171528773 and parameters: {'classifier': 'SVM', 'C': 1.434025530821701, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:59,230] Trial 31 finished with value: 0.7768452096285668 and parameters: {'classifier': 'RandomForest', 'n_estimators': 193, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 7, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:21:59,649] Trial 32 finished with value: 0.7833333333333333 and parameters: {'classifier': 'RandomForest', 'n_estimators': 74, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:22:00,109] Trial 33 finished with value: 0.7833413040012753 and parameters: {'classifier': 'RandomForest', 'n_estimators': 76, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 6 with value: 0.7866092778574845.
# [I 2024-12-20 14:22:00,584] Trial 34 finished with value: 0.7882193527817631 and parameters: {'classifier': 'RandomForest', 'n_estimators': 79, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:01,112] Trial 35 finished with value: 0.7475689462776981 and parameters: {'classifier': 'RandomForest', 'n_estimators': 111, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:01,164] Trial 36 finished with value: 0.6970508528614697 and parameters: {'classifier': 'SVM', 'C': 2.155069659177969, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:03,987] Trial 37 finished with value: 0.7442770604176631 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 88, 'learning_rate': 0.04134965069349602, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:04,677] Trial 38 finished with value: 0.771975131516021 and parameters: {'classifier': 'RandomForest', 'n_estimators': 137, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:05,749] Trial 39 finished with value: 0.7735931771082417 and parameters: {'classifier': 'RandomForest', 'n_estimators': 172, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 5, 'bootstrap': True}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:10,161] Trial 40 finished with value: 0.7507731547903714 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 219, 'learning_rate': 0.010667756235532636, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:10,914] Trial 41 finished with value: 0.7833413040012753 and parameters: {'classifier': 'RandomForest', 'n_estimators': 76, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:11,336] Trial 42 finished with value: 0.7800813008130082 and parameters: {'classifier': 'RandomForest', 'n_estimators': 54, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:11,777] Trial 43 finished with value: 0.7833492746692173 and parameters: {'classifier': 'RandomForest', 'n_estimators': 75, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:13,324] Trial 44 finished with value: 0.7817152877411128 and parameters: {'classifier': 'RandomForest', 'n_estimators': 282, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:13,882] Trial 45 finished with value: 0.7719512195121951 and parameters: {'classifier': 'RandomForest', 'n_estimators': 91, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:14,570] Trial 46 finished with value: 0.7800733301450662 and parameters: {'classifier': 'RandomForest', 'n_estimators': 105, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:14,893] Trial 47 finished with value: 0.7117248525426431 and parameters: {'classifier': 'SVM', 'C': 82.43331893731495, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:16,367] Trial 48 finished with value: 0.7589749721026622 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 67, 'learning_rate': 0.09410819455366996, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 34 with value: 0.7882193527817631.
# [I 2024-12-20 14:22:17,053] Trial 49 finished with value: 0.7784552845528455 and parameters: {'classifier': 'RandomForest', 'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 34 with value: 0.7882193527817631.

# %%
def objective(trial):
    # Choose the algorithm to tune
    classifier_name = trial.suggest_categorical('classifier', ['SVM', 'RandomForest', 'GradientBoosting'])

    if classifier_name == 'SVM':
        # SVM hyperparameters
        c = trial.suggest_float('C', 0.1, 100, log=True)
        kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly', 'sigmoid'])
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])

        model = SVC(C=c, kernel=kernel, gamma=gamma, random_state=42)

    elif classifier_name == 'RandomForest':
        # Random Forest hyperparameters
        n_estimators = trial.suggest_int('n_estimators', 50, 300)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
        bootstrap = trial.suggest_categorical('bootstrap', [True, False])

        model = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            bootstrap=bootstrap,
            random_state=42
        )

    elif classifier_name == 'GradientBoosting':
        # Gradient Boosting hyperparameters
        n_estimators = trial.suggest_int('n_estimators', 50, 300)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log=True)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)

        model = GradientBoostingClassifier(
            n_estimators=n_estimators,
            learning_rate=learning_rate,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=
# 30 0 days 00:00:00.051226   1.434026              NaN               SVM
# 31 0 days 00:00:01.006673        NaN            False      RandomForest
# 32 0 days 00:00:00.417306        NaN            False      RandomForest
# 33 0 days 00:00:00.457693        NaN            False      RandomForest
# 34 0 days 00:00:00.470713        NaN            False      RandomForest
# 35 0 days 00:00:00.526673        NaN            False      RandomForest
# 36 0 days 00:00:00.050312   2.155070              NaN               SVM
# 37 0 days 00:00:02.820663        NaN              NaN  GradientBoosting
# 38 0 days 00:00:00.687798        NaN            False      RandomForest
# 39 0 days 00:00:01.070755        NaN             True      RandomForest
# 40 0 days 00:00:04.409734        NaN              NaN  GradientBoosting
# 41 0 days 00:00:00.745550        NaN            False      RandomForest
# 42 0 days 00:00:00.420187        NaN            False      RandomForest
# 43 0 days 00:00:00.438903        NaN            False      RandomForest
# 44 0 days 00:00:01.544300        NaN            False      RandomForest
# 45 0 days 00:00:00.556028        NaN            False      RandomForest
# 46 0 days 00:00:00.686178        NaN             True      RandomForest
# 47 0 days 00:00:00.321011  82.433319              NaN               SVM
# 48 0 days 00:00:01.472486        NaN              NaN  GradientBoosting
# 49 0 days 00:00:00.684258        NaN            False      RandomForest
#
#    params_gamma params_kernel  params_learning_rate  params_max_depth  \
# 0           NaN           NaN                   NaN               4.0
# 1           NaN           NaN              0.119427              10.0
# 2         scale           rbf                   NaN               NaN
# 3           NaN           NaN                   NaN              15.0
# 4          auto           rbf                   NaN               NaN
# 5           NaN           NaN              0.275757              11.0
# 6           NaN           NaN                   NaN              14.0
# 7           NaN           NaN                   NaN              18.0
# 8           NaN           NaN              0.230855              18.0
# 9           NaN           NaN              0.033327              15.0
# 10          NaN           NaN                   NaN               6.0
# 11          NaN           NaN                   NaN              14.0
# 12          NaN           NaN                   NaN              13.0
# 13          NaN           NaN                   NaN              20.0
# 14          NaN           NaN                   NaN               8.0
# 15          NaN           NaN                   NaN               8.0
# 16         auto        linear                   NaN               NaN
# 17          NaN           NaN                   NaN               8.0
# 18          NaN           NaN                   NaN               3.0
# 19        scale          poly                   NaN               NaN
# 20          NaN           NaN                   NaN               9.0
# 21          NaN           NaN                   NaN              16.0
# 22          NaN           NaN                   NaN              12.0
# 23          NaN           NaN                   NaN              12.0
# 24          NaN           NaN                   NaN               6.0
# 25          NaN           NaN                   NaN               6.0
# 26          NaN           NaN                   NaN               6.0
# 27          NaN           NaN                   NaN               5.0
# 28          NaN           NaN              0.013040               8.0
# 29          NaN           NaN                   NaN               7.0
# 30        scale       sigmoid                   NaN               NaN
# 31          NaN           NaN                   NaN              11.0
# 32          NaN           NaN                   NaN              13.0
# 33          NaN           NaN                   NaN              10.0
# 34          NaN           NaN                   NaN              10.0
# 35          NaN           NaN                   NaN               3.0
# 36         auto       sigmoid                   NaN               NaN
# 37          NaN           NaN              0.041350               9.0
# 38          NaN           NaN                   NaN               5.0
# 39          NaN           NaN                   NaN              10.0
# 40          NaN           NaN              0.010668               7.0
# 41          NaN           NaN                   NaN              10.0
# 42          NaN           NaN                   NaN               9.0
# 43          NaN           NaN                   NaN              11.0
# 44          NaN           NaN                   NaN              11.0
# 45          NaN           NaN                   NaN              16.0
# 46          NaN           NaN                   NaN              13.0
# 47        scale          poly                   NaN               NaN
# 48          NaN           NaN              0.094108              14.0
# 49          NaN           NaN                   NaN               7.0
#
#     params_min_samples_leaf  params_min_samples_split  params_n_estimators  \
# 0                       9.0                       4.0                200.0
# 1                       6.0                       5.0                278.0
# 2                       NaN                       NaN                  NaN
# 3                      10.0                       2.0                170.0
# 4                       NaN                       NaN                  NaN
# 5                       3.0                       8.0                 99.0
# 6                       3.0                       9.0                 98.0
# 7                       8.0                       8.0                251.0
# 8                       7.0                       7.0                220.0
# 9                       2.0                       3.0                 64.0
# 10                      4.0                      10.0                132.0
# 11                      1.0                       2.0                151.0
# 12                     10.0                      10.0                119.0
# 13                      5.0                       6.0                 54.0
# 14                      4.0                       2.0                178.0
# 15                      3.0                       9.0                198.0
# 16                      NaN                       NaN                  NaN
# 17                      5.0                       5.0                 86.0
# 18                      1.0                       7.0                157.0
# 19                      NaN                       NaN                  NaN
# 20                      3.0                       4.0                230.0
# 21                      4.0                       2.0                165.0
# 22                      6.0                       3.0                184.0
# 23                      6.0                       3.0                189.0
# 24                      4.0                       4.0                134.0
# 25                      4.0                       4.0                120.0
# 26                      2.0                       5.0                 93.0
# 27                      4.0                       3.0                132.0
# 28                      2.0                       6.0                142.0
# 29                      5.0                       9.0                108.0
# 30                      NaN                       NaN                  NaN
# 31                      7.0                       3.0                193.0
# 32                      6.0                       2.0                 74.0
# 33                      3.0                       2.0                 76.0
# 34                      3.0                       4.0                 79.0
# 35                      4.0                       6.0                111.0
# 36                      NaN                       NaN                  NaN
# 37                      2.0                       4.0                 88.0
# 38                      3.0                       5.0                137.0
# 39                      5.0                       4.0                172.0
# 40                      3.0                       5.0                219.0
# 41                      3.0                       2.0                 76.0
# 42                      4.0                       2.0                 54.0
# 43                      2.0                       7.0                 75.0
# 44                      2.0                       7.0                282.0
# 45                      1.0                       8.0                 91.0
# 46                      2.0                       9.0                105.0
# 47                      NaN                       NaN                  NaN
# 48                      4.0                       8.0                 67.0
# 49                      2.0                       6.0                121.0
#
#        state
# 0   COMPLETE
# 1   COMPLETE
# 2   COMPLETE
# 3   COMPLETE
# 4   COMPLETE
# 5   COMPLETE
# 6   COMPLETE
# 7   COMPLETE
# 8   COMPLETE
# 9   COMPLETE
# 10  COMPLETE
# 11  COMPLETE
# 12  COMPLETE
# 13  COMPLETE
# 14  COMPLETE
# 15  COMPLETE
# 16  COMPLETE
# 17  COMPLETE
# 18  COMPLETE
# 19  COMPLETE
# 20  COMPLETE
# 21  COMPLETE
# 22  COMPLETE
# 23  COMPLETE
# 24  COMPLETE
# 25  COMPLETE
# 26  COMPLETE
# 27  COMPLETE
# 28  COMPLETE
# 29  COMPLETE
# 30  COMPLETE
# 31  COMPLETE
# 32  COMPLETE
# 33  COMPLETE
# 34  COMPLETE
# 35  COMPLETE
# 36  COMPLETE
# 37  COMPLETE
# 38  COMPLETE
# 39  COMPLETE
# 40  COMPLETE
# 41  COMPLETE
# 42  COMPLETE
# 43  COMPLETE
# 44  COMPLETE
# 45  COMPLETE
# 46  COMPLETE
# 47  COMPLETE
# 48  COMPLETE
# 49  COMPLETE
